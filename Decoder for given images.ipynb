# %%
from IPython.display import Image, SVG
import matplotlib.pyplot as plt

# %matplotlib inline

import numpy as np
import keras
from keras.datasets import mnist
from keras.models import Model, Sequential
from keras.layers import Input, Dense, Conv2D, MaxPooling2D, UpSampling2D, Flatten, Reshape
from keras import regularizers
from keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing.image import load_img
from keras.preprocessing import image
from PIL import Image

from glob import glob
import os
import random

# %%
PATH = os.getcwd()
 
train_path = PATH+'/images/train/'
train_batch = os.listdir(train_path)
x_train = []
 
# if data are in form of images
for sample in train_batch:
	img_path = train_path+sample
	x = Image.open(img_path)
	# preprocessing if required
	x_train.append(x)
 
test_path = PATH+'/images/test/'
test_batch = os.listdir(test_path)
x_test = []
 
for sample in test_batch:
	img_path = test_path+sample
	x = Image.open(img_path)
	# preprocessing if required
	x_test.append(x)
print(x_train)
    
# finally converting list into numpy array
x_train = np.array(x_train)
x_test = np.array(x_test)
# Out:
# [<PIL.PngImagePlugin.PngImageFile image mode=P size=87x257 at 0x7A5EA58>, <PIL.PngImagePlugin.PngImageFile image mode=P size=100x257 at 0x7A5EB38>, <PIL.PngImagePlugin.PngImageFile image mode=P size=90x257 at 0x7A5EBE0>, <PIL.PngImagePlugin.PngImageFile image mode=P size=66x257 at 0x7A5EC88>, <PIL.PngImagePlugin.PngImageFile image mode=P size=62x257 at 0x7A5ED30>, <PIL.PngImagePlugin.PngImageFile image mode=P size=83x257 at 0x7A5EDD8>, <PIL.PngImagePlugin.PngImageFile image mode=P size=70x257 at 0x7A5EE80>, <PIL.PngImagePlugin.PngImageFile image mode=P size=71x257 at 0x7A5EF28>, <PIL.PngImagePlugin.PngImageFile image mode=P size=59x257 at 0x7A5EEB8>, <PIL.PngImagePlugin.PngImageFile image mode=P size=87x257 at 0x77200B8>, <PIL.PngImagePlugin.PngImageFile image mode=P size=100x257 at 0x7720160>, <PIL.PngImagePlugin.PngImageFile image mode=P size=90x257 at 0x7720208>, <PIL.PngImagePlugin.PngImageFile image mode=P size=66x257 at 0x77202B0>, <PIL.PngImagePlugin.PngImageFile image mode=P size=62x257 at 0x7720390>, <PIL.PngImagePlugin.PngImageFile image mode=P size=83x257 at 0x7720400>, <PIL.PngImagePlugin.PngImageFile image mode=P size=70x257 at 0x7B203C8>, <PIL.PngImagePlugin.PngImageFile image mode=P size=71x257 at 0x7B204E0>, <PIL.PngImagePlugin.PngImageFile image mode=P size=59x257 at 0x7B206D8>, <PIL.PngImagePlugin.PngImageFile image mode=P size=84x257 at 0x7B207B8>, <PIL.PngImagePlugin.PngImageFile image mode=P size=84x257 at 0x7B20668>, <PIL.PngImagePlugin.PngImageFile image mode=P size=87x257 at 0x7B20908>, <PIL.PngImagePlugin.PngImageFile image mode=P size=100x257 at 0x7B207F0>, <PIL.PngImagePlugin.PngImageFile image mode=P size=90x257 at 0x7B20A58>, <PIL.PngImagePlugin.PngImageFile image mode=P size=66x257 at 0x7B20940>, <PIL.PngImagePlugin.PngImageFile image mode=P size=62x257 at 0x7B20BA8>, <PIL.PngImagePlugin.PngImageFile image mode=P size=83x257 at 0x7B20A90>, <PIL.PngImagePlugin.PngImageFile image mode=P size=70x257 at 0x7B20CF8>, <PIL.PngImagePlugin.PngImageFile image mode=P size=71x257 at 0x7B20BE0>, <PIL.PngImagePlugin.PngImageFile image mode=P size=59x257 at 0x7B20E48>, <PIL.PngImagePlugin.PngImageFile image mode=P size=84x257 at 0x7B20D30>, <PIL.PngImagePlugin.PngImageFile image mode=P size=87x257 at 0x7B20F98>, <PIL.PngImagePlugin.PngImageFile image mode=P size=100x257 at 0x7B20E80>, <PIL.PngImagePlugin.PngImageFile image mode=P size=90x257 at 0x7B20F60>, <PIL.PngImagePlugin.PngImageFile image mode=P size=66x257 at 0x63010B8>, <PIL.PngImagePlugin.PngImageFile image mode=P size=62x257 at 0x6301278>, <PIL.PngImagePlugin.PngImageFile image mode=P size=83x257 at 0x6301160>, <PIL.PngImagePlugin.PngImageFile image mode=P size=70x257 at 0x63013C8>, <PIL.PngImagePlugin.PngImageFile image mode=P size=71x257 at 0x63012B0>, <PIL.PngImagePlugin.PngImageFile image mode=P size=59x257 at 0x6301518>, <PIL.PngImagePlugin.PngImageFile image mode=P size=84x257 at 0x6301400>, <PIL.PngImagePlugin.PngImageFile image mode=P size=87x257 at 0x6301668>, <PIL.PngImagePlugin.PngImageFile image mode=P size=100x257 at 0x6301550>, <PIL.PngImagePlugin.PngImageFile image mode=P size=90x257 at 0x12CF7908>, <PIL.PngImagePlugin.PngImageFile image mode=P size=66x257 at 0x12CF7A58>, <PIL.PngImagePlugin.PngImageFile image mode=P size=62x257 at 0x12CF7B38>, <PIL.PngImagePlugin.PngImageFile image mode=P size=83x257 at 0x1C0E8978>, <PIL.PngImagePlugin.PngImageFile image mode=P size=70x257 at 0x1C0E8940>, <PIL.PngImagePlugin.PngImageFile image mode=P size=71x257 at 0x1C0E8A58>, <PIL.PngImagePlugin.PngImageFile image mode=P size=59x257 at 0x1C0E8B70>, <PIL.PngImagePlugin.PngImageFile image mode=P size=84x257 at 0x1C0E8BA8>, <PIL.PngImagePlugin.PngImageFile image mode=P size=87x257 at 0x1C0E8BE0>, <PIL.PngImagePlugin.PngImageFile image mode=P size=100x257 at 0x1C0E8CF8>, <PIL.PngImagePlugin.PngImageFile image mode=P size=90x257 at 0x1C0E8E80>, <PIL.PngImagePlugin.PngImageFile image mode=P size=66x257 at 0x1C0E8B38>, <PIL.PngImagePlugin.PngImageFile image  ...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-7f2f69898145> in <module>
#      24
#      25 # finally converting list into numpy array
# ---> 26 x_train = np.array(x_train)
#      27 x_test = np.array(x_test)
#
# TypeError: int() argument must be a string, a bytes-like object or a number, not 'PngImageFile'

# %%
# ../train/
PATH = os.path.abspath(os.path.join('..', 'train'))

# ../train/*.png
images = glob(os.path.join(PATH, "*.png"))

# %%
# ../test/
PATH = os.path.abspath(os.path.join('..', 'train'))

# ../test/*.png
x_test = glob(os.path.join(PATH, "*.png"))

# %%
max_value = float(x_train.max())
x_train = x_train.astype('float32') / max_value
x_test = x_test.astype('float32') / max_value
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-74-44bb35909004> in <module>
# ----> 1 max_value = float(x_train.max())
#       2 x_train = x_train.astype('float32') / max_value
#       3 x_test = x_test.astype('float32') / max_value
#
# AttributeError: 'list' object has no attribute 'max'

# %%
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))

(x_train.shape, x_test.shape)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-53-6d1cc65ef284> in <module>
# ----> 1 x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
#       2 x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))
#       3
#       4 (x_train.shape, x_test.shape)
#
# AttributeError: 'list' object has no attribute 'reshape'

# %%
def proc_images():

    x = [] # images as arrays
    y = [] # labels Infiltration or Not_infiltration
    WIDTH = 80
    HEIGHT = 257

    for img in images:
        base = os.path.basename(img)
        finding = labels["Finding Labels"][labels["Image Index"] == base].values[0]

        # Read and resize image
        full_size_image = cv2.imread(img)
        x.append(cv2.resize(full_size_image, (WIDTH,HEIGHT), interpolation=cv2.INTER_CUBIC))
        
    return x

# %%
x = proc_images()
# Set it up as a dataframe if you like
df = pd.DataFrame()
df["images"]=x
print(len(df), df.images[0].shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-65-e1edb78411f9> in <module>
#       1 x = proc_images()
#       2 # Set it up as a dataframe if you like
# ----> 3 df = pd.DataFrame()
#       4 df["images"]=x
#       5 print(len(df), df.images[0].shape)
#
# NameError: name 'pd' is not defined
